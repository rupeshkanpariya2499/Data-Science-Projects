# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("bmw.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
categorical_cols = [col for col in df.columns if df[col].dtype == "O"]
numerical_cols = [col for col in df.columns if df[col].dtype !="O"]

# %%
def show_value_counts(df, cols):
    for col in categorical_cols:
        print(f"\n{col}")
        print('------------------')
        print(df[col].value_counts()
             )

# %%
show_value_counts(df,categorical_cols)
# Out:
# model
# ------------------
# model
# 3 Series    2443
# 1 Series    1969
# 2 Series    1229
# 5 Series    1056
# 4 Series     995
# X1           804
# X3           551
# X5           468
# X2           288
# X4           179
# M4           125
# 6 Series     108
# Z4           108
# 7 Series     106
# X6           106
# X7            55
# i3            43
# 8 Series      39
# M5            29
# M3            27
# M2            21
# i8            17
# M6             8
# Z3             7
# Name: count, dtype: int64
#
# transmission
# ------------------
# transmission
# Semi-Auto    4666
# Automatic    3588
# Manual       2527
# Name: count, dtype: int64
#
# fuelType
# ------------------
# fuelType
# Diesel      7027
# Petrol      3417
# Hybrid       298
# Other         36
# Electric       3
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %%
df['age'] = 2025 - df['year']

# %%
sns.barplot(data = df, x = 'transmission', y = 'price', palette='viridis')
plt.title('price by transmission')
plt.show()
# Out:
# /var/folders/ty/z8kbc2997fdcqzyylhqv4nv80000gn/T/ipykernel_4416/1894900255.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = df, x = 'transmission', y = 'price', palette='viridis')

# %%
plt.title('price by fuel type')

sns.boxplot(data = df, x = 'fuelType', y = 'price', palette='viridis')
# Out:
# /var/folders/ty/z8kbc2997fdcqzyylhqv4nv80000gn/T/ipykernel_4416/1696525425.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = df, x = 'fuelType', y = 'price', palette='viridis')
# <Axes: title={'center': 'price by fuel type'}, xlabel='fuelType', ylabel='price'>

# %%
sns.scatterplot(data = df, x = 'year',y = 'price')
plt.title('price by year')

plt.show()

# %%
sns.scatterplot(data = df, x = 'mileage', y = 'price')
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %% [raw]
# handleging outliers

# %%
df = df[df['price']<90000]

# %%
sns.scatterplot(y = df['mpg'], x = df['fuelType'])
# Out:
# <Axes: xlabel='fuelType', ylabel='mpg'>

# %%
df["mileage_per_year"] = df["mileage"] / (df["age"] + 1)

# %%
sns.scatterplot(data = df, x = 'mileage_per_year',y= 'price')
plt.show()

# %%
df["tax_per_engine"] = df["tax"] / (df["engineSize"] + 0.1)

# %% [markdown]
# encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10779 entries, 0 to 10780
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             10779 non-null  object
#  1   year              10779 non-null  int64
#  2   price             10779 non-null  int64
#  3   transmission      10779 non-null  object
#  4   mileage           10779 non-null  int64
#  5   fuelType          10779 non-null  object
#  6   tax               10779 non-null  int64
#  7   mpg               10779 non-null  float64
#  8   engineSize        10779 non-null  float64
#  9   age               10779 non-null  int64
#  10  mileage_per_year  10779 non-null  float64
#  11  tax_per_engine    10779 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 1.1+ MB

# %%
categorical_cols = ['model','transmission', 'fuelType']

# %%
df = pd.get_dummies(df,columns = categorical_cols,drop_first=True,dtype=int)

# %%
df
# Out:
#        year  price  mileage  tax   mpg  engineSize  age  mileage_per_year  \
# 0      2014  11200    67068  125  57.6         2.0   11       5589.000000
# 1      2018  27000    14827  145  42.8         2.0    7       1853.375000
# 2      2016  16000    62794  160  51.4         3.0    9       6279.400000
# 3      2017  12750    26676  145  72.4         1.5    8       2964.000000
# 4      2014  14500    39554  160  50.4         3.0   11       3296.166667
# ...     ...    ...      ...  ...   ...         ...  ...               ...
# 10776  2016  19000    40818  150  54.3         2.0    9       4081.800000
# 10777  2016  14600    42947  125  60.1         2.0    9       4294.700000
# 10778  2017  13100    25468  200  42.8         2.0    8       2829.777778
# 10779  2014   9930    45000   30  64.2         2.0   11       3750.000000
# 10780  2017  15981    59432  125  57.6         2.0    8       6603.555556
#
#        tax_per_engine  model_ 2 Series  ...  model_ Z3  model_ Z4  model_ i3  \
# ...

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10779.000000  10779.000000   10779.000000  10779.000000  10779.000000
# mean    2017.079228  22716.900918   25498.545505    131.696818     56.400028
# std        2.349148  11350.934705   25144.281495     61.485685     31.338837
# min     1996.000000   1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000  14950.000000    5530.000000    135.000000     45.600000
# 50%     2017.000000  20460.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000  27928.000000   38207.500000    145.000000     62.800000
# max     2020.000000  89990.000000  214000.000000    580.000000    470.800000
#
#          engineSize           age  mileage_per_year  tax_per_engine  \
# count  10779.000000  10779.000000      10779.000000    10779.000000
# mean       2.167706      7.920772       2500.990691       61.188134
# std        0.552044      2.349148       2130.393961       81.246602
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('price',axis=1)
y = df['price']

# %%
X_train,X_test,y_train,y_test = train_test_split(
    X,y,
    test_size=0.25,
    random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# scaling

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %% [markdown]
# model predicting

# %%
model = XGBRegressor()
model2 = LGBMRegressor()

# %%
model.fit(X_train_scaled,y_train)
y_pred = model.predict(X_test_scaled)

model2.fit(X_train_scaled,y_train)
y_pred2 = model2.predict(X_test_scaled)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001050 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 815
# [LightGBM] [Info] Number of data points in the train set: 8084, number of used features: 32
# [LightGBM] [Info] Start training from score 22762.275359
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print('r2 : ', r2_score(y_test,y_pred))
print('mae : ', mean_absolute_error(y_test,y_pred))
print('mse : ', mean_squared_error(y_test,y_pred))
# Out:
# r2 :  0.9566246271133423
# mae :  1530.093017578125
# mse :  5525020.5

# %%
print('r2 : ', r2_score(y_test,y_pred2))
print('mae : ', mean_absolute_error(y_test,y_pred2))
print('mse : ', mean_squared_error(y_test,y_pred2))
# Out:
# r2 :  0.9533424448880283
# mae :  1576.6123590106877
# mse :  5943093.561894648

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    "n_estimators": [200, 400, 600],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [3, 5, 7],
    "min_child_weight": [1, 3, 5],
    "subsample": [0.7, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0],
    "gamma": [0, 0.1, 0.3],
    "reg_alpha": [0, 0.1, 1],
    "reg_lambda": [1, 1.5, 2],
}

# %%
grid= GridSearchCV(estimator=XGBRegressor(),param_grid=params,cv=5,verbose=1,n_jobs=-1)

# %% [markdown]
# this took 1 hour of mine

# %%
grid.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 19683 candidates, totalling 98415 fits
# Exception ignored on calling ctypes callback function <bound method DataIter._next_wrapper of <xgboost.data.SingleBatchInternalIter object at 0x128c535f0>>:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py", line 630, in _next_wrapper
#     def _next_wrapper(self, this: None) -> int:  # pylint: disable=unused-argument
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 grid.fit(X_train_scaled,y_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
# ...

# %%
y_pred3 = grid.predict(X_test_scaled)

# %%
print('r2 : ', r2_score(y_test,y_pred3))
print('mae : ', mean_absolute_error(y_test,y_pred3))
print('mse : ', mean_squared_error(y_test,y_pred3))
# Out:
# r2 :  0.9613734483718872
# mae :  1454.75048828125
# mse :  4920129.0
